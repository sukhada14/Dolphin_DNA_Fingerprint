# %%
import os
import re
import numpy as np
import pandas as pd
import process_fasta
import process_fasta_scaffold
from collections import defaultdict

# %%
def read_in_df(path):
    
    with open(path) as f:
        lines = f.readlines()[:-1]
        
    scaffold_lines = []
    for i, l in enumerate(lines):
        if 'QMGA' in l:
            print(l)
            scaffold_lines.append(i)
   
    dfs = []
    for i in range(len(scaffold_lines)):
        
        
        if i != len(scaffold_lines)-1:
            start = scaffold_lines[i] +7
            end = scaffold_lines[i+1]- 2
        else:
            start = scaffold_lines[i] +7
            end = len(lines)
        
        #print(start, end)
        columns = ['Start_Index', 'End_Index', 'Period_Size', 'Copy_Number', 'Consensus_Size' , 'Percent_Matches', 'Percent_Indels', 'Score', 'A' , 'C' ,'G', 'T', 'Entropy', 'Motif', 'Tandem_Repeat']

        rows = []
        for line in lines[start: end]:
            line = line.replace('\n', '')
            row = []
            for element in line.split(' '):
                if element.isdigit():
                    row.append(int(element))
                elif '.' in element and element[: element.find('.')].isdigit():
                    row.append(float(element))
                else:
                    row.append(element)

            if len(row) == 15:
                rows.append(row)

        df = pd.DataFrame(rows, columns = columns)
        rearrange  = ['Start_Index', 'End_Index', 'Motif', 'Tandem_Repeat', 'Period_Size', 'Copy_Number', 'Consensus_Size' , 'Percent_Matches', 'Percent_Indels', 'Score', 'A' , 'C' ,'G', 'T', 'Entropy']
        dfs.append(df[rearrange])
    
    return dfs

# %% [markdown]
# ## Read .dat file of donor1

# %%
#Reading donor1 data
df_d1 = read_in_df("../Data/Donor1/GCA_003314715.1_Tur_tru_Illumina_hap_v1_genomic.fna.2.7.7.80.10.50.500.dat")
# Out:
# Sequence: QMGA01000001.1 Tursiops truncatus isolate Sample_04329 scaffold1, whole genome shotgun sequence
#
# Sequence: QMGA01000010.1 Tursiops truncatus isolate Sample_04329 scaffold10, whole genome shotgun sequence
#
# Sequence: QMGA01000099.1 Tursiops truncatus isolate Sample_04329 scaffold100, whole genome shotgun sequence
#
# Sequence: QMGA01000100.1 Tursiops truncatus isolate Sample_04329 scaffold101, whole genome shotgun sequence
#
# Sequence: QMGA01000101.1 Tursiops truncatus isolate Sample_04329 scaffold102, whole genome shotgun sequence
#
# Sequence: QMGA01000102.1 Tursiops truncatus isolate Sample_04329 scaffold103, whole genome shotgun sequence
#
# Sequence: QMGA01000103.1 Tursiops truncatus isolate Sample_04329 scaffold104, whole genome shotgun sequence
#
# Sequence: QMGA01000104.1 Tursiops truncatus isolate Sample_04329 scaffold105, whole genome shotgun sequence
#
# Sequence: QMGA01000105.1 Tursiops truncatus isolate Sample_04329 scaffold106, whole genome shotgun sequence
#
# Sequence: QMGA01000106.1 Tursiops truncatus isolate Sample_04329 scaffold107, whole genome shotgun sequence
#
# Sequence: QMGA01000107.1 Tursiops truncatus isolate Sample_04329 scaffold108, whole genome shotgun sequence
#
# Sequence: QMGA01000108.1 Tursiops truncatus isolate Sample_04329 scaffold109, whole genome shotgun sequence
#
# Sequence: QMGA01000011.1 Tursiops truncatus isolate Sample_04329 scaffold11, whole genome shotgun sequence
#
# Sequence: QMGA01000109.1 Tursiops truncatus isolate Sample_04329 scaffold110, whole genome shotgun sequence
#
# Sequence: QMGA01000110.1 Tursiops truncatus isolate Sample_04329 scaffold111, whole genome shotgun sequence
#
# Sequence: QMGA01000111.1 Tursiops truncatus isolate Sample_04329 scaffold112, whole genome shotgun sequence
#
# Sequence: QMGA01000112.1 Tursiops truncatus isolate Sample_04329 scaffold113, whole genome shotgun sequence
#
# Sequence: QMGA01000113.1 Tursiops truncatus isolate Sample_04329 scaffold114, whole genome shotgun sequence
#
# Sequence: QMGA01000114.1 Tursiops truncatus isolate Sample_04329 scaffold115, whole genome shotgun sequence
#
# Sequence: QMGA01000115.1 Tursiops truncatus isolate Sample_04329 scaffold116, whole genome shotgun sequence
#
# Sequence: QMGA01000116.1 Tursiops truncatus isolate Sample_04329 scaffold117, whole genome shotgun sequence
#
# Sequence: QMGA01000117.1 Tursiops truncatus isolate Sample_04329 scaffold118, whole genome shotgun sequence
#
# Sequence: QMGA01000012.1 Tursiops truncatus isolate Sample_04329 scaffold12, whole genome shotgun sequence
#
# Sequence: QMGA01000118.1 Tursiops truncatus isolate Sample_04329 scaffold120, whole genome shotgun sequence
#
# Sequence: QMGA01000119.1 Tursiops truncatus isolate Sample_04329 scaffold121, whole genome shotgun sequence
#
# Sequence: QMGA01000120.1 Tursiops truncatus isolate Sample_04329 scaffold122, whole genome shotgun sequence
#
# Sequence: QMGA01000121.1 Tursiops truncatus isolate Sample_04329 scaffold123, whole genome shotgun sequence
#
# Sequence: QMGA01000122.1 Tursiops truncatus isolate Sample_04329 scaffold124, whole genome shotgun sequence
#
# Sequence: QMGA01000123.1 Tursiops truncatus isolate Sample_04329 scaffold125, whole genome shotgun sequence
#
# Sequence: QMGA01000124.1 Tursiops truncatus isolate Sample_04329 scaffold126, whole genome shotgun sequence
#
# Sequence: QMGA01000125.1 Tursiops truncatus isolate Sample_04329 scaffold127, whole genome shotgun sequence
#
# Sequence: QMGA01000126.1 Tursiops truncatus isolate Sample_04329 scaffold128, whole genome shotgun sequence
#
# Sequence: QMGA01000127.1 Tursiops truncatus isolate Sample_04329 scaffold129, whole genome shotgun sequence
#
# Sequence: QMGA01000013.1 Tursiops truncatus isolate Sample_04329 scaffold13, whole genome shotgun sequence
#
# Sequence: QMGA01000128.1 Tursiops truncatus isolate Sample_04329 scaffold130, whole genome shotgun sequence
#
# Sequence: QMGA01000129.1 Tursiops truncatus isolate Sample_04329 scaffold131, whole genome shotgun sequence
#
# Sequence: QMGA01000130.1 Tursiops truncatus isolate Sample_04329 scaffold132, whole genome shotgun sequence
#
# Sequence: QMGA01000131.1 Tursiops truncatus isolate Sample_04329 scaffold133, whole genome shotgun sequence
#
# Sequence: QMGA01000132.1 Tursiops truncatus isolate Sample_04329 scaffold134, whole genome shotgun sequence
#
# Sequence: QMGA01000133.1 Tursiops truncatus isolate Sample_04329 scaffold135, whole genome shotgun sequence
#
# Sequence: QMGA01000134.1 Tursiops truncatus isolate Sample_04329 scaffold136, whole genome shotgun sequence
#
# Sequence: QMGA01000135.1 Tursiops truncatus isolate Sample_04329 scaffold137, whole genome shotgun sequence
#
# Sequence: QMGA01000136.1 Tursiops truncatus isolate Sample_04329 scaffold138, whole genome shotgun sequence
#
# Sequence: QMGA01000137.1 Tursiops truncatus isolate Sample_04329 scaffold139, whole genome shotgun sequence
#
# Sequence: QMGA01000014.1 Tursiops truncatus isolate Sample_04329 scaffold14, whole genome shotgun sequence
#
# Sequence: QMGA01000138.1 Tursiops truncatus isolate Sample_04329 scaffold140, whole genome shotgun sequence
#
# Sequence: QMGA01000139.1 Tursiops truncatus isolate Sample_04329 scaffold141, whole genome shotgun sequence
#
# Sequence: QMGA01000140.1 Tursiops truncatus isolate Sample_04329 scaffold142, whole genome shotgun sequence
#
# Sequence: QMGA01000141.1 Tursiops truncatus isolate Sample_04329 scaffold143, whole genome shotgun sequence
#
# Sequence: QMGA01000142.1 Tursiops truncatus isolate Sample_04329 scaffold144, whole genome shotgun sequence
#
# Sequence: QMGA01000143.1 Tursiops truncatus isolate Sample_04329 scaffold145, whole genome shotgun sequence
#
# Sequence: QMGA01000144.1 Tursiops truncatus isolate Sample_04329 scaffold146, whole genome shotgun sequence
#
# Sequence: QMGA01000145.1 Tursiops truncatus isolate Sample_04329 scaffold147, whole genome shotgun sequence
#
# Sequence: QMGA01000146.1 Tursiops truncatus isolate Sample_04329 scaffold148, whole genome shotgun sequence
#
# Sequence: QMGA01000147.1 Tursiops truncatus isolate Sample_04329 scaffold149, whole genome shotgun sequence
#
# Sequence: QMGA01000015.1 Tursiops truncatus isolate Sample_04329 scaffold15, whole genome shotgun sequence
#
# Sequence: QMGA01000148.1 Tursiops truncatus isolate Sample_04329 scaffold150, whole genome shotgun sequence
#
# Sequence: QMGA01000149.1 Tursiops truncatus isolate Sample_04329 scaffold151, whole genome shotgun sequence
#
# Sequence: QMGA01000150.1 Tursiops truncatus isolate Sample_04329 scaffold152, whole genome shotgun sequence
#
# Sequence: QMGA01000151.1 Tursiops truncatus isolate Sample_04329 scaffold153, whole genome shotgun sequence
#
# Sequence: QMGA01000152.1 Tursiops truncatus isolate Sample_04329 scaffold154, whole genome shotgun sequence
#
# Sequence: QMGA01000153.1 Tursiops truncatus isolate Sample_04329 scaffold155, whole genome shotgun sequence
#
# Sequence: QMGA01000154.1 Tursiops truncatus isolate Sample_04329 scaffold156, whole genome shotgun sequence
#
# Sequence: QMGA01000155.1 Tursiops truncatus isolate Sample_04329 scaffold157, whole genome shotgun sequence
#
# Sequence: QMGA01000156.1 Tursiops truncatus isolate Sample_04329 scaffold158, whole genome shotgun sequence
#
# Sequence: QMGA01000157.1 Tursiops truncatus isolate Sample_04329 scaffold159, whole genome shotgun sequence
#
# Sequence: QMGA01000016.1 Tursiops truncatus isolate Sample_04329 scaffold16, whole genome shotgun sequence
#
# Sequence: QMGA01000158.1 Tursiops truncatus isolate Sample_04329 scaffold160, whole genome shotgun sequence
#
# Sequence: QMGA01000159.1 Tursiops truncatus isolate Sample_04329 scaffold161, whole genome shotgun sequence
#
# Sequence: QMGA01000160.1 Tursiops truncatus isolate Sample_04329 scaffold162, whole genome shotgun sequence
#
# Sequence: QMGA01000161.1 Tursiops truncatus isolate Sample_04329 scaffold163, whole genome shotgun sequence
#
# Sequence: QMGA01000162.1 Tursiops truncatus isolate Sample_04329 scaffold164, whole genome shotgun sequence
#
# Sequence: QMGA01000163.1 Tursiops truncatus isolate Sample_04329 scaffold165, whole genome shotgun sequence
#
# Sequence: QMGA01000164.1 Tursiops truncatus isolate Sample_04329 scaffold166, whole genome shotgun sequence
#
# Sequence: QMGA01000165.1 Tursiops truncatus isolate Sample_04329 scaffold169, whole genome shotgun sequence
#
# Sequence: QMGA01000017.1 Tursiops truncatus isolate Sample_04329 scaffold17, whole genome shotgun sequence
#
# Sequence: QMGA01000166.1 Tursiops truncatus isolate Sample_04329 scaffold170, whole genome shotgun sequence
#
# Sequence: QMGA01000167.1 Tursiops truncatus isolate Sample_04329 scaffold171, whole genome shotgun sequence
#
# Sequence: QMGA01000168.1 Tursiops truncatus isolate Sample_04329 scaffold172, whole genome shotgun sequence
#
# Sequence: QMGA01000169.1 Tursiops truncatus isolate Sample_04329 scaffold173, whole genome shotgun sequence
#
# Sequence: QMGA01000170.1 Tursiops truncatus isolate Sample_04329 scaffold174, whole genome shotgun sequence
#
# Sequence: QMGA01000171.1 Tursiops truncatus isolate Sample_04329 scaffold175, whole genome shotgun sequence
#
# Sequence: QMGA01000172.1 Tursiops truncatus isolate Sample_04329 scaffold176, whole genome shotgun sequence
#
# Sequence: QMGA01000173.1 Tursiops truncatus isolate Sample_04329 scaffold177, whole genome shotgun sequence
#
# Sequence: QMGA01000174.1 Tursiops truncatus isolate Sample_04329 scaffold178, whole genome shotgun sequence
#
# Sequence: QMGA01000175.1 Tursiops truncatus isolate Sample_04329 scaffold179, whole genome shotgun sequence
#
# Sequence: QMGA01000018.1 Tursiops truncatus isolate Sample_04329 scaffold18, whole genome shotgun sequence
#
# Sequence: QMGA01000176.1 Tursiops truncatus isolate Sample_04329 scaffold180, whole genome shotgun sequence
#
# Sequence: QMGA01000177.1 Tursiops truncatus isolate Sample_04329 scaffold181, whole genome shotgun sequence
#
# Sequence: QMGA01000178.1 Tursiops truncatus isolate Sample_04329 scaffold182, whole genome shotgun sequence
#
# Sequence: QMGA01000179.1 Tursiops truncatus isolate Sample_04329 scaffold183, whole genome shotgun sequence
#
# Sequence: QMGA01000180.1 Tursiops truncatus isolate Sample_04329 scaffold184, whole genome shotgun sequence
#
# Sequence: QMGA01000181.1 Tursiops truncatus isolate Sample_04329 scaffold185, whole genome shotgun sequence
#
# Sequence: QMGA01000182.1 Tursiops truncatus isolate Sample_04329 scaffold186, whole genome shotgun sequence
#
# Sequence: QMGA01000183.1 Tursiops truncatus isolate Sample_04329 scaffold187, whole genome shotgun sequence
#
# Sequence: QMGA01000184.1 Tursiops truncatus isolate Sample_04329 scaffold188, whole genome shotgun sequence
#
# Sequence: QMGA01000185.1 Tursiops truncatus isolate Sample_04329 scaffold189, whole genome shotgun sequence
#
# Sequence: QMGA01000019.1 Tursiops truncatus isolate Sample_04329 scaffold19, whole genome shotgun sequence
#
# Sequence: QMGA01000186.1 Tursiops truncatus isolate Sample_04329 scaffold190, whole genome shotgun sequence
#
# Sequence: QMGA01000187.1 Tursiops truncatus isolate Sample_04329 scaffold191, whole genome shotgun sequence
#
# Sequence: QMGA01000188.1 Tursiops truncatus isolate Sample_04329 scaffold192, whole genome shotgun sequence
#
# Sequence: QMGA01000189.1 Tursiops truncatus isolate Sample_04329 scaffold193, whole genome shotgun sequence
#
# Sequence: QMGA01000190.1 Tursiops truncatus isolate Sample_04329 scaffold194, whole genome shotgun sequence
#
# Sequence: QMGA01000191.1 Tursiops truncatus isolate Sample_04329 scaffold195, whole genome shotgun sequence
#
# Sequence: QMGA01000192.1 Tursiops truncatus isolate Sample_04329 scaffold196, whole genome shotgun sequence
#
# Sequence: QMGA01000193.1 Tursiops truncatus isolate Sample_04329 scaffold197, whole genome shotgun sequence
#
# Sequence: QMGA01000194.1 Tursiops truncatus isolate Sample_04329 scaffold198, whole genome shotgun sequence
#
# Sequence: QMGA01000195.1 Tursiops truncatus isolate Sample_04329 scaffold199, whole genome shotgun sequence
#
# Sequence: QMGA01000002.1 Tursiops truncatus isolate Sample_04329 scaffold2, whole genome shotgun sequence
#
# Sequence: QMGA01000020.1 Tursiops truncatus isolate Sample_04329 scaffold20, whole genome shotgun sequence
#
# Sequence: QMGA01000196.1 Tursiops truncatus isolate Sample_04329 scaffold200, whole genome shotgun sequence
#
# Sequence: QMGA01000197.1 Tursiops truncatus isolate Sample_04329 scaffold201, whole genome shotgun sequence
#
# Sequence: QMGA01000198.1 Tursiops truncatus isolate Sample_04329 scaffold202, whole genome shotgun sequence
#
# Sequence: QMGA01000199.1 Tursiops truncatus isolate Sample_04329 scaffold203, whole genome shotgun sequence
#
# Sequence: QMGA01000200.1 Tursiops truncatus isolate Sample_04329 scaffold204, whole genome shotgun sequence
#
# Sequence: QMGA01000201.1 Tursiops truncatus isolate Sample_04329 scaffold205, whole genome shotgun sequence
#
# Sequence: QMGA01000202.1 Tursiops truncatus isolate Sample_04329 scaffold206, whole genome shotgun sequence
#
# Sequence: QMGA01000203.1 Tursiops truncatus isolate Sample_04329 scaffold207, whole genome shotgun sequence
#
# Sequence: QMGA01000204.1 Tursiops truncatus isolate Sample_04329 scaffold208, whole genome shotgun sequence
#
# Sequence: QMGA01000205.1 Tursiops truncatus isolate Sample_04329 scaffold209, whole genome shotgun sequence
#
# Sequence: QMGA01000206.1 Tursiops truncatus isolate Sample_04329 scaffold210, whole genome shotgun sequence
#
# Sequence: QMGA01000207.1 Tursiops truncatus isolate Sample_04329 scaffold211, whole genome shotgun sequence
#
# Sequence: QMGA01000208.1 Tursiops truncatus isolate Sample_04329 scaffold212, whole genome shotgun sequence
#
# Sequence: QMGA01000209.1 Tursiops truncatus isolate Sample_04329 scaffold213, whole genome shotgun sequence
#
# Sequence: QMGA01000210.1 Tursiops truncatus isolate Sample_04329 scaffold214, whole genome shotgun sequence
#
# Sequence: QMGA01000211.1 Tursiops truncatus isolate Sample_04329 scaffold215, whole genome shotgun sequence
#
# Sequence: QMGA01000212.1 Tursiops truncatus isolate Sample_04329 scaffold216, whole genome shotgun sequence
#
# Sequence: QMGA01000213.1 Tursiops truncatus isolate Sample_04329 scaffold217, whole genome shotgun sequence
#
# Sequence: QMGA01000214.1 Tursiops truncatus isolate Sample_04329 scaffold218, whole genome shotgun sequence
#
# Sequence: QMGA01000215.1 Tursiops truncatus isolate Sample_04329 scaffold219, whole genome shotgun sequence
#
# Sequence: QMGA01000021.1 Tursiops truncatus isolate Sample_04329 scaffold22, whole genome shotgun sequence
#
# Sequence: QMGA01000216.1 Tursiops truncatus isolate Sample_04329 scaffold220, whole genome shotgun sequence
#
# Sequence: QMGA01000217.1 Tursiops truncatus isolate Sample_04329 scaffold221, whole genome shotgun sequence
#
# Sequence: QMGA01000218.1 Tursiops truncatus isolate Sample_04329 scaffold222, whole genome shotgun sequence
#
# Sequence: QMGA01000219.1 Tursiops truncatus isolate Sample_04329 scaffold223, whole genome shotgun sequence
#
# Sequence: QMGA01000220.1 Tursiops truncatus isolate Sample_04329 scaffold224, whole genome shotgun sequence
#
# Sequence: QMGA01000221.1 Tursiops truncatus isolate Sample_04329 scaffold225, whole genome shotgun sequence
#
# Sequence: QMGA01000222.1 Tursiops truncatus isolate Sample_04329 scaffold226, whole genome shotgun sequence
#
# Sequence: QMGA01000223.1 Tursiops truncatus isolate Sample_04329 scaffold227, whole genome shotgun sequence
#
# Sequence: QMGA01000224.1 Tursiops truncatus isolate Sample_04329 scaffold229, whole genome shotgun sequence
#
# Sequence: QMGA01000022.1 Tursiops truncatus isolate Sample_04329 scaffold23, whole genome shotgun sequence
#
# Sequence: QMGA01000225.1 Tursiops truncatus isolate Sample_04329 scaffold230, whole genome shotgun sequence
#
# Sequence: QMGA01000226.1 Tursiops truncatus isolate Sample_04329 scaffold231, whole genome shotgun sequence
#
# Sequence: QMGA01000227.1 Tursiops truncatus isolate Sample_04329 scaffold232, whole genome shotgun sequence
#
# Sequence: QMGA01000228.1 Tursiops truncatus isolate Sample_04329 scaffold233, whole genome shotgun sequence
#
# Sequence: QMGA01000229.1 Tursiops truncatus isolate Sample_04329 scaffold234, whole genome shotgun sequence
#
# Sequence: QMGA01000230.1 Tursiops truncatus isolate Sample_04329 scaffold235, whole genome shotgun sequence
#
# Sequence: QMGA01000231.1 Tursiops truncatus isolate Sample_04329 scaffold236, whole genome shotgun sequence
#
# Sequence: QMGA01000232.1 Tursiops truncatus isolate Sample_04329 scaffold237, whole genome shotgun sequence
#
# Sequence: QMGA01000233.1 Tursiops truncatus isolate Sample_04329 scaffold238, whole genome shotgun sequence
#
# Sequence: QMGA01000234.1 Tursiops truncatus isolate Sample_04329 scaffold239, whole genome shotgun sequence
#
# Sequence: QMGA01000023.1 Tursiops truncatus isolate Sample_04329 scaffold24, whole genome shotgun sequence
#
# Sequence: QMGA01000235.1 Tursiops truncatus isolate Sample_04329 scaffold240, whole genome shotgun sequence
#
# Sequence: QMGA01000236.1 Tursiops truncatus isolate Sample_04329 scaffold241, whole genome shotgun sequence
#
# Sequence: QMGA01000237.1 Tursiops truncatus isolate Sample_04329 scaffold242, whole genome shotgun sequence
#
# Sequence: QMGA01000238.1 Tursiops truncatus isolate Sample_04329 scaffold243, whole genome shotgun sequence
#
# Sequence: QMGA01000239.1 Tursiops truncatus isolate Sample_04329 scaffold244, whole genome shotgun sequence
#
# Sequence: QMGA01000240.1 Tursiops truncatus isolate Sample_04329 scaffold245, whole genome shotgun sequence
#
# Sequence: QMGA01000241.1 Tursiops truncatus isolate Sample_04329 scaffold246, whole genome shotgun sequence
#
# Sequence: QMGA01000242.1 Tursiops truncatus isolate Sample_04329 scaffold247, whole genome shotgun sequence
#
# Sequence: QMGA01000243.1 Tursiops truncatus isolate Sample_04329 scaffold248, whole genome shotgun sequence
#
# Sequence: QMGA01000244.1 Tursiops truncatus isolate Sample_04329 scaffold249, whole genome shotgun sequence
#
# Sequence: QMGA01000024.1 Tursiops truncatus isolate Sample_04329 scaffold25, whole genome shotgun sequence
#
# Sequence: QMGA01000245.1 Tursiops truncatus isolate Sample_04329 scaffold250, whole genome shotgun sequence
#
# Sequence: QMGA01000246.1 Tursiops truncatus isolate Sample_04329 scaffold251, whole genome shotgun sequence
#
# Sequence: QMGA01000247.1 Tursiops truncatus isolate Sample_04329 scaffold252, whole genome shotgun sequence
#
# Sequence: QMGA01000248.1 Tursiops truncatus isolate Sample_04329 scaffold253, whole genome shotgun sequence
#
# Sequence: QMGA01000249.1 Tursiops truncatus isolate Sample_04329 scaffold254, whole genome shotgun sequence
#
# Sequence: QMGA01000250.1 Tursiops truncatus isolate Sample_04329 scaffold255, whole genome shotgun sequence
#
# Sequence: QMGA01000251.1 Tursiops truncatus isolate Sample_04329 scaffold256, whole genome shotgun sequence
#
# Sequence: QMGA01000252.1 Tursiops truncatus isolate Sample_04329 scaffold257, whole genome shotgun sequence
#
# Sequence: QMGA01000253.1 Tursiops truncatus isolate Sample_04329 scaffold258, whole genome shotgun sequence
#
# Sequence: QMGA01000254.1 Tursiops truncatus isolate Sample_04329 scaffold259, whole genome shotgun sequence
#
# Sequence: QMGA01000025.1 Tursiops truncatus isolate Sample_04329 scaffold26, whole genome shotgun sequence
#
# Sequence: QMGA01000255.1 Tursiops truncatus isolate Sample_04329 scaffold260, whole genome shotgun sequence
#
# Sequence: QMGA01000256.1 Tursiops truncatus isolate Sample_04329 scaffold261, whole genome shotgun sequence
#
# Sequence: QMGA01000257.1 Tursiops truncatus isolate Sample_04329 scaffold262, whole genome shotgun sequence
#
# Sequence: QMGA01000258.1 Tursiops truncatus isolate Sample_04329 scaffold263, whole genome shotgun sequence
#
# Sequence: QMGA01000259.1 Tursiops truncatus isolate Sample_04329 scaffold264, whole genome shotgun sequence
#
# Sequence: QMGA01000260.1 Tursiops truncatus isolate Sample_04329 scaffold265, whole genome shotgun sequence
#
# Sequence: QMGA01000261.1 Tursiops truncatus isolate Sample_04329 scaffold266, whole genome shotgun sequence
#
# Sequence: QMGA01000262.1 Tursiops truncatus isolate Sample_04329 scaffold267, whole genome shotgun sequence
#
# Sequence: QMGA01000263.1 Tursiops truncatus isolate Sample_04329 scaffold268, whole genome shotgun sequence
#
# Sequence: QMGA01000264.1 Tursiops truncatus isolate Sample_04329 scaffold269, whole genome shotgun sequence
#
# Sequence: QMGA01000026.1 Tursiops truncatus isolate Sample_04329 scaffold27, whole genome shotgun sequence
#
# Sequence: QMGA01000265.1 Tursiops truncatus isolate Sample_04329 scaffold270, whole genome shotgun sequence
#
# Sequence: QMGA01000266.1 Tursiops truncatus isolate Sample_04329 scaffold271, whole genome shotgun sequence
#
# Sequence: QMGA01000267.1 Tursiops truncatus isolate Sample_04329 scaffold272, whole genome shotgun sequence
#
# Sequence: QMGA01000268.1 Tursiops truncatus isolate Sample_04329 scaffold273, whole genome shotgun sequence
#
# Sequence: QMGA01000269.1 Tursiops truncatus isolate Sample_04329 scaffold274, whole genome shotgun sequence
#
# Sequence: QMGA01000270.1 Tursiops truncatus isolate Sample_04329 scaffold275, whole genome shotgun sequence
#
# Sequence: QMGA01000271.1 Tursiops truncatus isolate Sample_04329 scaffold276, whole genome shotgun sequence
#
# Sequence: QMGA01000272.1 Tursiops truncatus isolate Sample_04329 scaffold277, whole genome shotgun sequence
#
# Sequence: QMGA01000273.1 Tursiops truncatus isolate Sample_04329 scaffold278, whole genome shotgun sequence
#
# Sequence: QMGA01000274.1 Tursiops truncatus isolate Sample_04329 scaffold279, whole genome shotgun sequence
#
# Sequence: QMGA01000027.1 Tursiops truncatus isolate Sample_04329 scaffold28, whole genome shotgun sequence
#
# Sequence: QMGA01000275.1 Tursiops truncatus isolate Sample_04329 scaffold280, whole genome shotgun sequence
#
# Sequence: QMGA01000276.1 Tursiops truncatus isolate Sample_04329 scaffold281, whole genome shotgun sequence
#
# Sequence: QMGA01000277.1 Tursiops truncatus isolate Sample_04329 scaffold282, whole genome shotgun sequence
#
# Sequence: QMGA01000278.1 Tursiops truncatus isolate Sample_04329 scaffold283, whole genome shotgun sequence
#
# Sequence: QMGA01000279.1 Tursiops truncatus isolate Sample_04329 scaffold284, whole genome shotgun sequence
#
# Sequence: QMGA01000280.1 Tursiops truncatus isolate Sample_04329 scaffold285, whole genome shotgun sequence
#
# Sequence: QMGA01000281.1 Tursiops truncatus isolate Sample_04329 scaffold286, whole genome shotgun sequence
#
# Sequence: QMGA01000282.1 Tursiops truncatus isolate Sample_04329 scaffold287, whole genome shotgun sequence
#
# Sequence: QMGA01000283.1 Tursiops truncatus isolate Sample_04329 scaffold288, whole genome shotgun sequence
#
# Sequence: QMGA01000284.1 Tursiops truncatus isolate Sample_04329 scaffold289, whole genome shotgun sequence
#
# Sequence: QMGA01000028.1 Tursiops truncatus isolate Sample_04329 scaffold29, whole genome shotgun sequence
#
# Sequence: QMGA01000285.1 Tursiops truncatus isolate Sample_04329 scaffold290, whole genome shotgun sequence
#
# Sequence: QMGA01000286.1 Tursiops truncatus isolate Sample_04329 scaffold291, whole genome shotgun sequence
#
# Sequence: QMGA01000287.1 Tursiops truncatus isolate Sample_04329 scaffold292, whole genome shotgun sequence
#
# Sequence: QMGA01000288.1 Tursiops truncatus isolate Sample_04329 scaffold293, whole genome shotgun sequence
#
# Sequence: QMGA01000289.1 Tursiops truncatus isolate Sample_04329 scaffold294, whole genome shotgun sequence
#
# Sequence: QMGA01000290.1 Tursiops truncatus isolate Sample_04329 scaffold295, whole genome shotgun sequence
#
# Sequence: QMGA01000291.1 Tursiops truncatus isolate Sample_04329 scaffold296, whole genome shotgun sequence
#
# Sequence: QMGA01000292.1 Tursiops truncatus isolate Sample_04329 scaffold297, whole genome shotgun sequence
#
# Sequence: QMGA01000293.1 Tursiops truncatus isolate Sample_04329 scaffold298, whole genome shotgun sequence
#
# Sequence: QMGA01000294.1 Tursiops truncatus isolate Sample_04329 scaffold299, whole genome shotgun sequence
#
# Sequence: QMGA01000003.1 Tursiops truncatus isolate Sample_04329 scaffold3, whole genome shotgun sequence
#
# Sequence: QMGA01000029.1 Tursiops truncatus isolate Sample_04329 scaffold30, whole genome shotgun sequence
#
# Sequence: QMGA01000295.1 Tursiops truncatus isolate Sample_04329 scaffold300, whole genome shotgun sequence
#
# Sequence: QMGA01000296.1 Tursiops truncatus isolate Sample_04329 scaffold301, whole genome shotgun sequence
#
# Sequence: QMGA01000297.1 Tursiops truncatus isolate Sample_04329 scaffold302, whole genome shotgun sequence
#
# Sequence: QMGA01000298.1 Tursiops truncatus isolate Sample_04329 scaffold303, whole genome shotgun sequence
#
# Sequence: QMGA01000299.1 Tursiops truncatus isolate Sample_04329 scaffold304, whole genome shotgun sequence
#
# Sequence: QMGA01000300.1 Tursiops truncatus isolate Sample_04329 scaffold305, whole genome shotgun sequence
#
# Sequence: QMGA01000301.1 Tursiops truncatus isolate Sample_04329 scaffold306, whole genome shotgun sequence
#
# Sequence: QMGA01000302.1 Tursiops truncatus isolate Sample_04329 scaffold307, whole genome shotgun sequence
#
# Sequence: QMGA01000303.1 Tursiops truncatus isolate Sample_04329 scaffold308, whole genome shotgun sequence
#
# Sequence: QMGA01000304.1 Tursiops truncatus isolate Sample_04329 scaffold309, whole genome shotgun sequence
#
# Sequence: QMGA01000030.1 Tursiops truncatus isolate Sample_04329 scaffold31, whole genome shotgun sequence
#
# Sequence: QMGA01000305.1 Tursiops truncatus isolate Sample_04329 scaffold310, whole genome shotgun sequence
#
# Sequence: QMGA01000306.1 Tursiops truncatus isolate Sample_04329 scaffold311, whole genome shotgun sequence
#
# Sequence: QMGA01000307.1 Tursiops truncatus isolate Sample_04329 scaffold312, whole genome shotgun sequence
#
# Sequence: QMGA01000308.1 Tursiops truncatus isolate Sample_04329 scaffold313, whole genome shotgun sequence
#
# Sequence: QMGA01000309.1 Tursiops truncatus isolate Sample_04329 scaffold314, whole genome shotgun sequence
#
# Sequence: QMGA01000310.1 Tursiops truncatus isolate Sample_04329 scaffold315, whole genome shotgun sequence
#
# Sequence: QMGA01000311.1 Tursiops truncatus isolate Sample_04329 scaffold316, whole genome shotgun sequence
#
# Sequence: QMGA01000312.1 Tursiops truncatus isolate Sample_04329 scaffold317, whole genome shotgun sequence
#
# Sequence: QMGA01000313.1 Tursiops truncatus isolate Sample_04329 scaffold318, whole genome shotgun sequence
#
# Sequence: QMGA01000314.1 Tursiops truncatus isolate Sample_04329 scaffold319, whole genome shotgun sequence
#
# Sequence: QMGA01000031.1 Tursiops truncatus isolate Sample_04329 scaffold32, whole genome shotgun sequence
#
# Sequence: QMGA01000315.1 Tursiops truncatus isolate Sample_04329 scaffold320, whole genome shotgun sequence
#
# Sequence: QMGA01000316.1 Tursiops truncatus isolate Sample_04329 scaffold321, whole genome shotgun sequence
#
# Sequence: QMGA01000317.1 Tursiops truncatus isolate Sample_04329 scaffold322, whole genome shotgun sequence
#
# Sequence: QMGA01000318.1 Tursiops truncatus isolate Sample_04329 scaffold323, whole genome shotgun sequence
#
# Sequence: QMGA01000319.1 Tursiops truncatus isolate Sample_04329 scaffold324, whole genome shotgun sequence
#
# Sequence: QMGA01000320.1 Tursiops truncatus isolate Sample_04329 scaffold325, whole genome shotgun sequence
#
# Sequence: QMGA01000321.1 Tursiops truncatus isolate Sample_04329 scaffold326, whole genome shotgun sequence
#
# Sequence: QMGA01000322.1 Tursiops truncatus isolate Sample_04329 scaffold327, whole genome shotgun sequence
#
# Sequence: QMGA01000323.1 Tursiops truncatus isolate Sample_04329 scaffold328, whole genome shotgun sequence
#
# Sequence: QMGA01000324.1 Tursiops truncatus isolate Sample_04329 scaffold329, whole genome shotgun sequence
#
# Sequence: QMGA01000032.1 Tursiops truncatus isolate Sample_04329 scaffold33, whole genome shotgun sequence
#
# Sequence: QMGA01000325.1 Tursiops truncatus isolate Sample_04329 scaffold330, whole genome shotgun sequence
#
# Sequence: QMGA01000326.1 Tursiops truncatus isolate Sample_04329 scaffold331, whole genome shotgun sequence
#
# Sequence: QMGA01000327.1 Tursiops truncatus isolate Sample_04329 scaffold333, whole genome shotgun sequence
#
# Sequence: QMGA01000328.1 Tursiops truncatus isolate Sample_04329 scaffold334, whole genome shotgun sequence
#
# Sequence: QMGA01000329.1 Tursiops truncatus isolate Sample_04329 scaffold335, whole genome shotgun sequence
#
# Sequence: QMGA01000330.1 Tursiops truncatus isolate Sample_04329 scaffold337, whole genome shotgun sequence
#
# Sequence: QMGA01000331.1 Tursiops truncatus isolate Sample_04329 scaffold338, whole genome shotgun sequence
#
# Sequence: QMGA01000332.1 Tursiops truncatus isolate Sample_04329 scaffold339, whole genome shotgun sequence
#
# Sequence: QMGA01000033.1 Tursiops truncatus isolate Sample_04329 scaffold34, whole genome shotgun sequence
#
# Sequence: QMGA01000333.1 Tursiops truncatus isolate Sample_04329 scaffold340, whole genome shotgun sequence
#
# Sequence: QMGA01000334.1 Tursiops truncatus isolate Sample_04329 scaffold341, whole genome shotgun sequence
#
# Sequence: QMGA01000335.1 Tursiops truncatus isolate Sample_04329 scaffold342, whole genome shotgun sequence
#
# Sequence: QMGA01000336.1 Tursiops truncatus isolate Sample_04329 scaffold343, whole genome shotgun sequence
#
# Sequence: QMGA01000337.1 Tursiops truncatus isolate Sample_04329 scaffold344, whole genome shotgun sequence
#
# Sequence: QMGA01000338.1 Tursiops truncatus isolate Sample_04329 scaffold345, whole genome shotgun sequence
#
# Sequence: QMGA01000339.1 Tursiops truncatus isolate Sample_04329 scaffold346, whole genome shotgun sequence
#
# Sequence: QMGA01000340.1 Tursiops truncatus isolate Sample_04329 scaffold347, whole genome shotgun sequence
#
# Sequence: QMGA01000341.1 Tursiops truncatus isolate Sample_04329 scaffold348, whole genome shotgun sequence
#
# Sequence: QMGA01000342.1 Tursiops truncatus isolate Sample_04329 scaffold349, whole genome shotgun sequence
#
# Sequence: QMGA01000034.1 Tursiops truncatus isolate Sample_04329 scaffold35, whole genome shotgun sequence
#
# Sequence: QMGA01000343.1 Tursiops truncatus isolate Sample_04329 scaffold350, whole genome shotgun sequence
#
# Sequence: QMGA01000344.1 Tursiops truncatus isolate Sample_04329 scaffold351, whole genome shotgun sequence
#
# Sequence: QMGA01000345.1 Tursiops truncatus isolate Sample_04329 scaffold352, whole genome shotgun sequence
#
# Sequence: QMGA01000346.1 Tursiops truncatus isolate Sample_04329 scaffold353, whole genome shotgun sequence
#
# Sequence: QMGA01000347.1 Tursiops truncatus isolate Sample_04329 scaffold354, whole genome shotgun sequence
#
# Sequence: QMGA01000348.1 Tursiops truncatus isolate Sample_04329 scaffold355, whole genome shotgun sequence
#
# Sequence: QMGA01000349.1 Tursiops truncatus isolate Sample_04329 scaffold356, whole genome shotgun sequence
#
# Sequence: QMGA01000350.1 Tursiops truncatus isolate Sample_04329 scaffold357, whole genome shotgun sequence
#
# Sequence: QMGA01000351.1 Tursiops truncatus isolate Sample_04329 scaffold358, whole genome shotgun sequence
#
# Sequence: QMGA01000352.1 Tursiops truncatus isolate Sample_04329 scaffold359, whole genome shotgun sequence
#
# Sequence: QMGA01000035.1 Tursiops truncatus isolate Sample_04329 scaffold36, whole genome shotgun sequence
#
# Sequence: QMGA01000353.1 Tursiops truncatus isolate Sample_04329 scaffold360, whole genome shotgun sequence
#
# Sequence: QMGA01000354.1 Tursiops truncatus isolate Sample_04329 scaffold361, whole genome shotgun sequence
#
# Sequence: QMGA01000355.1 Tursiops truncatus isolate Sample_04329 scaffold362, whole genome shotgun sequence
#
# Sequence: QMGA01000356.1 Tursiops truncatus isolate Sample_04329 scaffold363, whole genome shotgun sequence
#
# Sequence: QMGA01000357.1 Tursiops truncatus isolate Sample_04329 scaffold364, whole genome shotgun sequence
#
# Sequence: QMGA01000358.1 Tursiops truncatus isolate Sample_04329 scaffold365, whole genome shotgun sequence
#
# Sequence: QMGA01000359.1 Tursiops truncatus isolate Sample_04329 scaffold366, whole genome shotgun sequence
#
# Sequence: QMGA01000360.1 Tursiops truncatus isolate Sample_04329 scaffold367, whole genome shotgun sequence
#
# Sequence: QMGA01000361.1 Tursiops truncatus isolate Sample_04329 scaffold368, whole genome shotgun sequence
#
# Sequence: QMGA01000362.1 Tursiops truncatus isolate Sample_04329 scaffold369, whole genome shotgun sequence
#
# Sequence: QMGA01000036.1 Tursiops truncatus isolate Sample_04329 scaffold37, whole genome shotgun sequence
#
# Sequence: QMGA01000363.1 Tursiops truncatus isolate Sample_04329 scaffold370, whole genome shotgun sequence
#
# Sequence: QMGA01000364.1 Tursiops truncatus isolate Sample_04329 scaffold371, whole genome shotgun sequence
#
# Sequence: QMGA01000365.1 Tursiops truncatus isolate Sample_04329 scaffold372, whole genome shotgun sequence
#
# Sequence: QMGA01000366.1 Tursiops truncatus isolate Sample_04329 scaffold373, whole genome shotgun sequence
#
# Sequence: QMGA01000367.1 Tursiops truncatus isolate Sample_04329 scaffold374, whole genome shotgun sequence
#
# Sequence: QMGA01000368.1 Tursiops truncatus isolate Sample_04329 scaffold375, whole genome shotgun sequence
#
# Sequence: QMGA01000369.1 Tursiops truncatus isolate Sample_04329 scaffold376, whole genome shotgun sequence
#
# Sequence: QMGA01000370.1 Tursiops truncatus isolate Sample_04329 scaffold377, whole genome shotgun sequence
#
# Sequence: QMGA01000371.1 Tursiops truncatus isolate Sample_04329 scaffold378, whole genome shotgun sequence
#
# Sequence: QMGA01000372.1 Tursiops truncatus isolate Sample_04329 scaffold379, whole genome shotgun sequence
#
# Sequence: QMGA01000037.1 Tursiops truncatus isolate Sample_04329 scaffold38, whole genome shotgun sequence
#
# Sequence: QMGA01000373.1 Tursiops truncatus isolate Sample_04329 scaffold380, whole genome shotgun sequence
#
# Sequence: QMGA01000374.1 Tursiops truncatus isolate Sample_04329 scaffold381, whole genome shotgun sequence
#
# Sequence: QMGA01000375.1 Tursiops truncatus isolate Sample_04329 scaffold382, whole genome shotgun sequence
#
# Sequence: QMGA01000376.1 Tursiops truncatus isolate Sample_04329 scaffold383, whole genome shotgun sequence
#
# Sequence: QMGA01000377.1 Tursiops truncatus isolate Sample_04329 scaffold384, whole genome shotgun sequence
#
# Sequence: QMGA01000378.1 Tursiops truncatus isolate Sample_04329 scaffold385, whole genome shotgun sequence
#
# Sequence: QMGA01000379.1 Tursiops truncatus isolate Sample_04329 scaffold386, whole genome shotgun sequence
#
# Sequence: QMGA01000380.1 Tursiops truncatus isolate Sample_04329 scaffold387, whole genome shotgun sequence
#
# Sequence: QMGA01000381.1 Tursiops truncatus isolate Sample_04329 scaffold388, whole genome shotgun sequence
#
# Sequence: QMGA01000382.1 Tursiops truncatus isolate Sample_04329 scaffold389, whole genome shotgun sequence
#
# Sequence: QMGA01000038.1 Tursiops truncatus isolate Sample_04329 scaffold39, whole genome shotgun sequence
#
# Sequence: QMGA01000383.1 Tursiops truncatus isolate Sample_04329 scaffold390, whole genome shotgun sequence
#
# Sequence: QMGA01000384.1 Tursiops truncatus isolate Sample_04329 scaffold391, whole genome shotgun sequence
#
# Sequence: QMGA01000385.1 Tursiops truncatus isolate Sample_04329 scaffold392, whole genome shotgun sequence
#
# Sequence: QMGA01000386.1 Tursiops truncatus isolate Sample_04329 scaffold393, whole genome shotgun sequence
#
# Sequence: QMGA01000387.1 Tursiops truncatus isolate Sample_04329 scaffold394, whole genome shotgun sequence
#
# Sequence: QMGA01000388.1 Tursiops truncatus isolate Sample_04329 scaffold395, whole genome shotgun sequence
#
# Sequence: QMGA01000389.1 Tursiops truncatus isolate Sample_04329 scaffold396, whole genome shotgun sequence
#
# Sequence: QMGA01000390.1 Tursiops truncatus isolate Sample_04329 scaffold397, whole genome shotgun sequence
#
# Sequence: QMGA01000391.1 Tursiops truncatus isolate Sample_04329 scaffold398, whole genome shotgun sequence
#
# Sequence: QMGA01000392.1 Tursiops truncatus isolate Sample_04329 scaffold399, whole genome shotgun sequence
#
# Sequence: QMGA01000004.1 Tursiops truncatus isolate Sample_04329 scaffold4, whole genome shotgun sequence
#
# Sequence: QMGA01000039.1 Tursiops truncatus isolate Sample_04329 scaffold40, whole genome shotgun sequence
#
# Sequence: QMGA01000393.1 Tursiops truncatus isolate Sample_04329 scaffold400, whole genome shotgun sequence
#
# Sequence: QMGA01000394.1 Tursiops truncatus isolate Sample_04329 scaffold401, whole genome shotgun sequence
#
# Sequence: QMGA01000395.1 Tursiops truncatus isolate Sample_04329 scaffold402, whole genome shotgun sequence
#
# Sequence: QMGA01000396.1 Tursiops truncatus isolate Sample_04329 scaffold403, whole genome shotgun sequence
#
# Sequence: QMGA01000397.1 Tursiops truncatus isolate Sample_04329 scaffold404, whole genome shotgun sequence
#
# Sequence: QMGA01000398.1 Tursiops truncatus isolate Sample_04329 scaffold405, whole genome shotgun sequence
#
# Sequence: QMGA01000399.1 Tursiops truncatus isolate Sample_04329 scaffold406, whole genome shotgun sequence
#
# Sequence: QMGA01000400.1 Tursiops truncatus isolate Sample_04329 scaffold407, whole genome shotgun sequence
#
# Sequence: QMGA01000401.1 Tursiops truncatus isolate Sample_04329 scaffold408, whole genome shotgun sequence
#
# Sequence: QMGA01000402.1 Tursiops truncatus isolate Sample_04329 scaffold409, whole genome shotgun sequence
#
# Sequence: QMGA01000040.1 Tursiops truncatus isolate Sample_04329 scaffold41, whole genome shotgun sequence
#
# Sequence: QMGA01000403.1 Tursiops truncatus isolate Sample_04329 scaffold410, whole genome shotgun sequence
#
# Sequence: QMGA01000404.1 Tursiops truncatus isolate Sample_04329 scaffold411, whole genome shotgun sequence
#
# Sequence: QMGA01000405.1 Tursiops truncatus isolate Sample_04329 scaffold412, whole genome shotgun sequence
#
# Sequence: QMGA01000406.1 Tursiops truncatus isolate Sample_04329 scaffold413, whole genome shotgun sequence
#
# Sequence: QMGA01000407.1 Tursiops truncatus isolate Sample_04329 scaffold414, whole genome shotgun sequence
#
# Sequence: QMGA01000408.1 Tursiops truncatus isolate Sample_04329 scaffold415, whole genome shotgun sequence
#
# Sequence: QMGA01000409.1 Tursiops truncatus isolate Sample_04329 scaffold416, whole genome shotgun sequence
#
# Sequence: QMGA01000410.1 Tursiops truncatus isolate Sample_04329 scaffold417, whole genome shotgun sequence
#
# Sequence: QMGA01000411.1 Tursiops truncatus isolate Sample_04329 scaffold418, whole genome shotgun sequence
#
# Sequence: QMGA01000412.1 Tursiops truncatus isolate Sample_04329 scaffold419, whole genome shotgun sequence
#
# Sequence: QMGA01000041.1 Tursiops truncatus isolate Sample_04329 scaffold42, whole genome shotgun sequence
#
# Sequence: QMGA01000413.1 Tursiops truncatus isolate Sample_04329 scaffold420, whole genome shotgun sequence
#
# Sequence: QMGA01000414.1 Tursiops truncatus isolate Sample_04329 scaffold421, whole genome shotgun sequence
#
# Sequence: QMGA01000415.1 Tursiops truncatus isolate Sample_04329 scaffold422, whole genome shotgun sequence
#
# Sequence: QMGA01000416.1 Tursiops truncatus isolate Sample_04329 scaffold423, whole genome shotgun sequence
#
# Sequence: QMGA01000417.1 Tursiops truncatus isolate Sample_04329 scaffold424, whole genome shotgun sequence
#
# Sequence: QMGA01000418.1 Tursiops truncatus isolate Sample_04329 scaffold425, whole genome shotgun sequence
#
# Sequence: QMGA01000419.1 Tursiops truncatus isolate Sample_04329 scaffold426, whole genome shotgun sequence
#
# Sequence: QMGA01000420.1 Tursiops truncatus isolate Sample_04329 scaffold427, whole genome shotgun sequence
#
# Sequence: QMGA01000421.1 Tursiops truncatus isolate Sample_04329 scaffold428, whole genome shotgun sequence
#
# Sequence: QMGA01000422.1 Tursiops truncatus isolate Sample_04329 scaffold429, whole genome shotgun sequence
#
# Sequence: QMGA01000042.1 Tursiops truncatus isolate Sample_04329 scaffold43, whole genome shotgun sequence
#
# Sequence: QMGA01000423.1 Tursiops truncatus isolate Sample_04329 scaffold430, whole genome shotgun sequence
#
# Sequence: QMGA01000424.1 Tursiops truncatus isolate Sample_04329 scaffold431, whole genome shotgun sequence
#
# Sequence: QMGA01000425.1 Tursiops truncatus isolate Sample_04329 scaffold432, whole genome shotgun sequence
#
# Sequence: QMGA01000426.1 Tursiops truncatus isolate Sample_04329 scaffold433, whole genome shotgun sequence
#
# Sequence: QMGA01000427.1 Tursiops truncatus isolate Sample_04329 scaffold434, whole genome shotgun sequence
#
# Sequence: QMGA01000428.1 Tursiops truncatus isolate Sample_04329 scaffold435, whole genome shotgun sequence
#
# Sequence: QMGA01000429.1 Tursiops truncatus isolate Sample_04329 scaffold436, whole genome shotgun sequence
#
# Sequence: QMGA01000430.1 Tursiops truncatus isolate Sample_04329 scaffold437, whole genome shotgun sequence
#
# Sequence: QMGA01000431.1 Tursiops truncatus isolate Sample_04329 scaffold438, whole genome shotgun sequence
#
# Sequence: QMGA01000432.1 Tursiops truncatus isolate Sample_04329 scaffold439, whole genome shotgun sequence
#
# Sequence: QMGA01000043.1 Tursiops truncatus isolate Sample_04329 scaffold44, whole genome shotgun sequence
#
# Sequence: QMGA01000433.1 Tursiops truncatus isolate Sample_04329 scaffold440, whole genome shotgun sequence
#
# Sequence: QMGA01000434.1 Tursiops truncatus isolate Sample_04329 scaffold441, whole genome shotgun sequence
#
# Sequence: QMGA01000435.1 Tursiops truncatus isolate Sample_04329 scaffold442, whole genome shotgun sequence
#
# Sequence: QMGA01000436.1 Tursiops truncatus isolate Sample_04329 scaffold443, whole genome shotgun sequence
#
# Sequence: QMGA01000437.1 Tursiops truncatus isolate Sample_04329 scaffold444, whole genome shotgun sequence
#
# Sequence: QMGA01000438.1 Tursiops truncatus isolate Sample_04329 scaffold445, whole genome shotgun sequence
#
# Sequence: QMGA01000439.1 Tursiops truncatus isolate Sample_04329 scaffold446, whole genome shotgun sequence
#
# Sequence: QMGA01000440.1 Tursiops truncatus isolate Sample_04329 scaffold447, whole genome shotgun sequence
#
# Sequence: QMGA01000441.1 Tursiops truncatus isolate Sample_04329 scaffold448, whole genome shotgun sequence
#
# Sequence: QMGA01000442.1 Tursiops truncatus isolate Sample_04329 scaffold449, whole genome shotgun sequence
#
# Sequence: QMGA01000044.1 Tursiops truncatus isolate Sample_04329 scaffold45, whole genome shotgun sequence
#
# Sequence: QMGA01000443.1 Tursiops truncatus isolate Sample_04329 scaffold450, whole genome shotgun sequence
#
# Sequence: QMGA01000444.1 Tursiops truncatus isolate Sample_04329 scaffold451, whole genome shotgun sequence
#
# Sequence: QMGA01000445.1 Tursiops truncatus isolate Sample_04329 scaffold452, whole genome shotgun sequence
#
# Sequence: QMGA01000446.1 Tursiops truncatus isolate Sample_04329 scaffold453, whole genome shotgun sequence
#
# Sequence: QMGA01000447.1 Tursiops truncatus isolate Sample_04329 scaffold454, whole genome shotgun sequence
#
# Sequence: QMGA01000448.1 Tursiops truncatus isolate Sample_04329 scaffold455, whole genome shotgun sequence
#
# Sequence: QMGA01000449.1 Tursiops truncatus isolate Sample_04329 scaffold456, whole genome shotgun sequence
#
# Sequence: QMGA01000450.1 Tursiops truncatus isolate Sample_04329 scaffold457, whole genome shotgun sequence
#
# Sequence: QMGA01000451.1 Tursiops truncatus isolate Sample_04329 scaffold458, whole genome shotgun sequence
#
# Sequence: QMGA01000452.1 Tursiops truncatus isolate Sample_04329 scaffold459, whole genome shotgun sequence
#
# Sequence: QMGA01000045.1 Tursiops truncatus isolate Sample_04329 scaffold46, whole genome shotgun sequence
#
# Sequence: QMGA01000453.1 Tursiops truncatus isolate Sample_04329 scaffold460, whole genome shotgun sequence
#
# Sequence: QMGA01000454.1 Tursiops truncatus isolate Sample_04329 scaffold461, whole genome shotgun sequence
#
# Sequence: QMGA01000455.1 Tursiops truncatus isolate Sample_04329 scaffold462, whole genome shotgun sequence
#
# Sequence: QMGA01000456.1 Tursiops truncatus isolate Sample_04329 scaffold463, whole genome shotgun sequence
#
# Sequence: QMGA01000457.1 Tursiops truncatus isolate Sample_04329 scaffold465, whole genome shotgun sequence
#
# Sequence: QMGA01000458.1 Tursiops truncatus isolate Sample_04329 scaffold467, whole genome shotgun sequence
#
# Sequence: QMGA01000459.1 Tursiops truncatus isolate Sample_04329 scaffold469, whole genome shotgun sequence
#
# Sequence: QMGA01000046.1 Tursiops truncatus isolate Sample_04329 scaffold47, whole genome shotgun sequence
#
# Sequence: QMGA01000460.1 Tursiops truncatus isolate Sample_04329 scaffold470, whole genome shotgun sequence
#
# Sequence: QMGA01000461.1 Tursiops truncatus isolate Sample_04329 scaffold471, whole genome shotgun sequence
#
# Sequence: QMGA01000462.1 Tursiops truncatus isolate Sample_04329 scaffold472, whole genome shotgun sequence
#
# Sequence: QMGA01000463.1 Tursiops truncatus isolate Sample_04329 scaffold473, whole genome shotgun sequence
#
# Sequence: QMGA01000464.1 Tursiops truncatus isolate Sample_04329 scaffold474, whole genome shotgun sequence
#
# Sequence: QMGA01000465.1 Tursiops truncatus isolate Sample_04329 scaffold475, whole genome shotgun sequence
#
# Sequence: QMGA01000466.1 Tursiops truncatus isolate Sample_04329 scaffold476, whole genome shotgun sequence
#
# Sequence: QMGA01000467.1 Tursiops truncatus isolate Sample_04329 scaffold477, whole genome shotgun sequence
#
# Sequence: QMGA01000468.1 Tursiops truncatus isolate Sample_04329 scaffold478, whole genome shotgun sequence
#
# Sequence: QMGA01000047.1 Tursiops truncatus isolate Sample_04329 scaffold48, whole genome shotgun sequence
#
# Sequence: QMGA01000469.1 Tursiops truncatus isolate Sample_04329 scaffold480, whole genome shotgun sequence
#
# Sequence: QMGA01000470.1 Tursiops truncatus isolate Sample_04329 scaffold481, whole genome shotgun sequence
#
# Sequence: QMGA01000471.1 Tursiops truncatus isolate Sample_04329 scaffold482, whole genome shotgun sequence
#
# Sequence: QMGA01000472.1 Tursiops truncatus isolate Sample_04329 scaffold483, whole genome shotgun sequence
#
# Sequence: QMGA01000473.1 Tursiops truncatus isolate Sample_04329 scaffold484, whole genome shotgun sequence
#
# Sequence: QMGA01000474.1 Tursiops truncatus isolate Sample_04329 scaffold485, whole genome shotgun sequence
#
# Sequence: QMGA01000475.1 Tursiops truncatus isolate Sample_04329 scaffold486, whole genome shotgun sequence
#
# Sequence: QMGA01000476.1 Tursiops truncatus isolate Sample_04329 scaffold487, whole genome shotgun sequence
#
# Sequence: QMGA01000477.1 Tursiops truncatus isolate Sample_04329 scaffold488, whole genome shotgun sequence
#
# Sequence: QMGA01000478.1 Tursiops truncatus isolate Sample_04329 scaffold489, whole genome shotgun sequence
#
# Sequence: QMGA01000048.1 Tursiops truncatus isolate Sample_04329 scaffold49, whole genome shotgun sequence
#
# Sequence: QMGA01000479.1 Tursiops truncatus isolate Sample_04329 scaffold490, whole genome shotgun sequence
#
# Sequence: QMGA01000480.1 Tursiops truncatus isolate Sample_04329 scaffold491, whole genome shotgun sequence
#
# Sequence: QMGA01000481.1 Tursiops truncatus isolate Sample_04329 scaffold492, whole genome shotgun sequence
#
# Sequence: QMGA01000005.1 Tursiops truncatus isolate Sample_04329 scaffold5, whole genome shotgun sequence
#
# Sequence: QMGA01000049.1 Tursiops truncatus isolate Sample_04329 scaffold50, whole genome shotgun sequence
#
# Sequence: QMGA01000050.1 Tursiops truncatus isolate Sample_04329 scaffold51, whole genome shotgun sequence
#
# Sequence: QMGA01000051.1 Tursiops truncatus isolate Sample_04329 scaffold52, whole genome shotgun sequence
#
# Sequence: QMGA01000052.1 Tursiops truncatus isolate Sample_04329 scaffold53, whole genome shotgun sequence
#
# Sequence: QMGA01000053.1 Tursiops truncatus isolate Sample_04329 scaffold54, whole genome shotgun sequence
#
# Sequence: QMGA01000054.1 Tursiops truncatus isolate Sample_04329 scaffold55, whole genome shotgun sequence
#
# Sequence: QMGA01000055.1 Tursiops truncatus isolate Sample_04329 scaffold56, whole genome shotgun sequence
#
# Sequence: QMGA01000056.1 Tursiops truncatus isolate Sample_04329 scaffold57, whole genome shotgun sequence
#
# Sequence: QMGA01000057.1 Tursiops truncatus isolate Sample_04329 scaffold58, whole genome shotgun sequence
#
# Sequence: QMGA01000058.1 Tursiops truncatus isolate Sample_04329 scaffold59, whole genome shotgun sequence
#
# Sequence: QMGA01000006.1 Tursiops truncatus isolate Sample_04329 scaffold6, whole genome shotgun sequence
#
# Sequence: QMGA01000059.1 Tursiops truncatus isolate Sample_04329 scaffold60, whole genome shotgun sequence
#
# Sequence: QMGA01000060.1 Tursiops truncatus isolate Sample_04329 scaffold61, whole genome shotgun sequence
#
# Sequence: QMGA01000061.1 Tursiops truncatus isolate Sample_04329 scaffold62, whole genome shotgun sequence
#
# Sequence: QMGA01000062.1 Tursiops truncatus isolate Sample_04329 scaffold63, whole genome shotgun sequence
#
# Sequence: QMGA01000063.1 Tursiops truncatus isolate Sample_04329 scaffold64, whole genome shotgun sequence
#
# Sequence: QMGA01000064.1 Tursiops truncatus isolate Sample_04329 scaffold65, whole genome shotgun sequence
#
# Sequence: QMGA01000065.1 Tursiops truncatus isolate Sample_04329 scaffold66, whole genome shotgun sequence
#
# Sequence: QMGA01000066.1 Tursiops truncatus isolate Sample_04329 scaffold67, whole genome shotgun sequence
#
# Sequence: QMGA01000067.1 Tursiops truncatus isolate Sample_04329 scaffold68, whole genome shotgun sequence
#
# Sequence: QMGA01000068.1 Tursiops truncatus isolate Sample_04329 scaffold69, whole genome shotgun sequence
#
# Sequence: QMGA01000007.1 Tursiops truncatus isolate Sample_04329 scaffold7, whole genome shotgun sequence
#
# Sequence: QMGA01000069.1 Tursiops truncatus isolate Sample_04329 scaffold70, whole genome shotgun sequence
#
# Sequence: QMGA01000070.1 Tursiops truncatus isolate Sample_04329 scaffold71, whole genome shotgun sequence
#
# Sequence: QMGA01000071.1 Tursiops truncatus isolate Sample_04329 scaffold72, whole genome shotgun sequence
#
# Sequence: QMGA01000072.1 Tursiops truncatus isolate Sample_04329 scaffold73, whole genome shotgun sequence
#
# Sequence: QMGA01000073.1 Tursiops truncatus isolate Sample_04329 scaffold74, whole genome shotgun sequence
#
# Sequence: QMGA01000074.1 Tursiops truncatus isolate Sample_04329 scaffold75, whole genome shotgun sequence
#
# Sequence: QMGA01000075.1 Tursiops truncatus isolate Sample_04329 scaffold76, whole genome shotgun sequence
#
# Sequence: QMGA01000076.1 Tursiops truncatus isolate Sample_04329 scaffold77, whole genome shotgun sequence
#
# Sequence: QMGA01000077.1 Tursiops truncatus isolate Sample_04329 scaffold78, whole genome shotgun sequence
#
# Sequence: QMGA01000078.1 Tursiops truncatus isolate Sample_04329 scaffold79, whole genome shotgun sequence
#
# Sequence: QMGA01000008.1 Tursiops truncatus isolate Sample_04329 scaffold8, whole genome shotgun sequence
#
# Sequence: QMGA01000079.1 Tursiops truncatus isolate Sample_04329 scaffold80, whole genome shotgun sequence
#
# Sequence: QMGA01000080.1 Tursiops truncatus isolate Sample_04329 scaffold81, whole genome shotgun sequence
#
# Sequence: QMGA01000081.1 Tursiops truncatus isolate Sample_04329 scaffold82, whole genome shotgun sequence
#
# Sequence: QMGA01000082.1 Tursiops truncatus isolate Sample_04329 scaffold83, whole genome shotgun sequence
#
# Sequence: QMGA01000083.1 Tursiops truncatus isolate Sample_04329 scaffold84, whole genome shotgun sequence
#
# Sequence: QMGA01000084.1 Tursiops truncatus isolate Sample_04329 scaffold85, whole genome shotgun sequence
#
# Sequence: QMGA01000085.1 Tursiops truncatus isolate Sample_04329 scaffold86, whole genome shotgun sequence
#
# Sequence: QMGA01000086.1 Tursiops truncatus isolate Sample_04329 scaffold87, whole genome shotgun sequence
#
# Sequence: QMGA01000087.1 Tursiops truncatus isolate Sample_04329 scaffold88, whole genome shotgun sequence
#
# Sequence: QMGA01000088.1 Tursiops truncatus isolate Sample_04329 scaffold89, whole genome shotgun sequence
#
# Sequence: QMGA01000009.1 Tursiops truncatus isolate Sample_04329 scaffold9, whole genome shotgun sequence
#
# Sequence: QMGA01000089.1 Tursiops truncatus isolate Sample_04329 scaffold90, whole genome shotgun sequence
#
# Sequence: QMGA01000090.1 Tursiops truncatus isolate Sample_04329 scaffold91, whole genome shotgun sequence
#
# Sequence: QMGA01000091.1 Tursiops truncatus isolate Sample_04329 scaffold92, whole genome shotgun sequence
#
# Sequence: QMGA01000092.1 Tursiops truncatus isolate Sample_04329 scaffold93, whole genome shotgun sequence
#
# Sequence: QMGA01000093.1 Tursiops truncatus isolate Sample_04329 scaffold94, whole genome shotgun sequence
#
# Sequence: QMGA01000094.1 Tursiops truncatus isolate Sample_04329 scaffold95, whole genome shotgun sequence
#
# Sequence: QMGA01000095.1 Tursiops truncatus isolate Sample_04329 scaffold96, whole genome shotgun sequence
#
# Sequence: QMGA01000096.1 Tursiops truncatus isolate Sample_04329 scaffold97, whole genome shotgun sequence
#
# Sequence: QMGA01000097.1 Tursiops truncatus isolate Sample_04329 scaffold98, whole genome shotgun sequence
#
# Sequence: QMGA01000098.1 Tursiops truncatus isolate Sample_04329 scaffold99, whole genome shotgun sequence

# %%
print([len(d) for d in df_d1])

# %%
sum([len(d) for d in df_d1])

# %% [markdown]
# ## Read Fasta file of the donor1

# %%
d1_genome_dict = process_fasta_scaffold.process_fasta_file('../Data/Donor1/GCA_003314715.1_Tur_tru_Illumina_hap_v1_genomic.fna')
# Out:
# Reading the FASTA file...
# Preprocessing the file...
# Collecting scaffold genomes
# DONE.

# %%
list(d1_genome_dict.keys())[-1]
# Out:
# '>QMGA01000098.1 Tursiops truncatus isolate Sample_04329 scaffold99, whole genome shotgun sequence'

# %% [markdown]
# ## Add flanking regions

# %%
def add_flanking_regions(df_d1, d1_genome_dict, fr_size):
    
    df_proc_d1 = []
    
    for i in range(len(df_d1)):
        
        
        lfrs = []
        rfrs = []
    
        genome = d1_genome_dict[list(d1_genome_dict.keys())[i]]
        temp = df_d1[i][(df_d1[i]['Start_Index'] > fr_size) & (df_d1[i]['End_Index'] + fr_size < len(genome))]     
        
        for j, row in temp.iterrows():
            lfr_start = row['Start_Index']-fr_size
            lfr_end = row['Start_Index']

            rfr_start = row['End_Index']
            rfr_end = row['End_Index']+fr_size

            lfr = genome[lfr_start:lfr_end]
            rfr = genome[rfr_start:rfr_end]

            lfrs.append(lfr)
            rfrs.append(rfr)
         
        if len(temp) != 0:
            temp.loc[:,'LFR'] = lfrs
            temp.loc[:,'RFR'] = rfrs      
        
        df_proc_d1.append(temp)
        
       # print(i, len(df_d1[i]), len(temp))
         
    return df_proc_d1

# %%
df_proc_d1 = add_flanking_regions(df_d1, d1_genome_dict, 100)

# %%
d1_genome_dict[list(d1_genome_dict.keys())[1]][14466:14524]

# %%
df_proc_d1[1].loc[1].Tandem_Repeat

# %%
for i in range(len(df_proc_d1)):
    df_proc_d1[i].to_csv('df_proc_d1_'+str(i)+'.csv', index = False)
